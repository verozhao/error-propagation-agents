# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.2/455.2 kB 36.3 MB/s eta 0:00:00
# ...

# %%
# !python run.py --mode run --models qwen-2.5-7b --trials 10
# Out:
# Running experiments:   0% 0/180 [00:00<?, ?it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
#
# Loading weights:   0% 0/339 [00:00<?, ?it/s]
# Loading weights:   0% 1/339 [00:00<00:00, 13231.24it/s, Materializing param=lm_head.weight]
# Loading weights:   0% 1/339 [00:00<00:00, 7145.32it/s, Materializing param=lm_head.weight]
# Loading weights:   1% 2/339 [00:00<01:25,  3.94it/s, Materializing param=lm_head.weight]
# Loading weights:   1% 2/339 [00:00<01:25,  3.94it/s, Materializing param=model.embed_tokens.weight]
# Loading weights:   1% 2/339 [00:00<01:25,  3.94it/s, Materializing param=model.embed_tokens.weight]
# Loading weights:   1% 3/339 [00:00<01:25,  3.94it/s, Materializing param=model.layers.0.input_layernorm.weight]
# Loading weights:   1% 3/339 [00:00<01:25,  3.94it/s, Materializing param=model.layers.0.input_layernorm.weight]
# ...

# %%
# !python run.py --mode run --models mistral-7b --trials 10
# Out:
# Running experiments:   0% 0/180 [00:00<?, ?it/s]
# config.json: 100% 601/601 [00:00<00:00, 3.98MB/s]
# ...
#
# tokenizer_config.json: 141kB [00:00, 74.8MB/s]
#
# tokenizer.json: 1.96MB [00:00, 175MB/s]
#
# tokenizer.model:   0% 0.00/587k [00:00<?, ?B/s]
# tokenizer.model: 100% 587k/587k [00:01<00:00, 527kB/s]
#
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 2.62MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
#
# model.safetensors.index.json: 23.9kB [00:00, 88.2MB/s]
#
# ...
#
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# ...
# ...
# Loading weights:  78% 227/291 [00:02<00:00, 80.62it/s, Materializing param=model.layers.24.self_attn.v_proj.weight]
# Loading weights:  78% 228/291 [00:02<00:00, 80.62it/s, Materializing param=model.layers.25.input_layernorm.weight]
# Loading weights:  78% 228/291 [00:02<00:00, 80.62it/s, Materializing param=model.layers.25.input_layernorm.weight]
# ...

# %%
import importlib
import models
importlib.reload(models)
# Out:
# <module 'models' from '/content/models.py'>

# %%
# !python run.py --mode run --models deepseek-r1-7b --trials 5
# Out:
# Running experiments:   0% 0/90 [00:00<?, ?it/s]`torch_dtype` is deprecated! Use `dtype` instead!
# ...
#
# Loading weights:   0% 0/339 [00:00<?, ?it/s]
# Loading weights:   0% 1/339 [00:00<00:00, 12710.01it/s, Materializing param=lm_head.weight]
# Loading weights:   0% 1/339 [00:00<00:00, 6754.11it/s, Materializing param=lm_head.weight]
# Loading weights:   1% 2/339 [00:00<00:40,  8.38it/s, Materializing param=lm_head.weight]
# Loading weights:   1% 2/339 [00:00<00:40,  8.38it/s, Materializing param=model.embed_tokens.weight]
# Loading weights:   1% 2/339 [00:00<00:40,  8.38it/s, Materializing param=model.embed_tokens.weight]
# Loading weights:   1% 3/339 [00:00<01:01,  5.42it/s, Materializing param=model.embed_tokens.weight]
# Loading weights:   1% 3/339 [00:00<01:01,  5.42it/s, Materializing param=model.layers.0.input_layernorm.weight]
# Loading weights:   1% 3/339 [00:00<01:01,  5.42it/s, Materializing param=model.layers.0.input_layernorm.weight]
# ...

# %%
# !pip install -q huggingface_hub

from huggingface_hub import login
login(token="....")

# %%
# !python run.py --mode run --models llama-3.1-8b --trials 10
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# ...
#
# Loading weights:  78% 228/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.input_layernorm.weight]
#
# Loading weights:  79% 229/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.down_proj.weight]
#
# Loading weights:  79% 229/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.down_proj.weight]
#
# Loading weights:  79% 230/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.gate_proj.weight]
#
# Loading weights:  79% 230/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.gate_proj.weight]
#
# Loading weights:  79% 231/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.up_proj.weight]
#
# Loading weights:  79% 231/291 [00:03<00:00, 79.27it/s, Materializing param=model.layers.25.mlp.up_proj.weight]
#
# Loading weights:  80% 232/291 [00:03<00:00, 79.12it/s, Materializing param=model.layers.25.mlp.up_proj.weight]
#
# ...
